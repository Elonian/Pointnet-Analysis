# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Change this path to the folder that contains Pointnet-Shape-Analysis.
PROJECT_DIR = '/content/drive/MyDrive/{path_to_dir}/Pointnet-Shape-Analysis'
POINTNET_DIR = f'{PROJECT_DIR}/sub-modules/pointnet'
print(PROJECT_DIR)
print(POINTNET_DIR)

# %%
# %cd $PROJECT_DIR
# !python -m pip install -r requirements.txt

# %%
# !mkdir -p "$POINTNET_DIR/data"
# !if [ -d "$PROJECT_DIR/data/modelnet40_ply_hdf5_2048" ]; then ln -sfn "$PROJECT_DIR/data/modelnet40_ply_hdf5_2048" "$POINTNET_DIR/data/modelnet40_ply_hdf5_2048"; fi
# !if [ -d "$PROJECT_DIR/data/shapenet_part_seg_hdf5_data" ]; then ln -sfn "$PROJECT_DIR/data/shapenet_part_seg_hdf5_data" "$POINTNET_DIR/data/shapenet_part_seg_hdf5_data"; fi
# %cd $POINTNET_DIR
# !ls -lah data

# %%
# !python -u train_cls.py --amp --epochs 20 --batch_size 128 --lr 0.001 --gpu 0

# %%
# !python -u train_seg.py --amp --epochs 20 --batch_size 128 --lr 0.001 --gpu 0
